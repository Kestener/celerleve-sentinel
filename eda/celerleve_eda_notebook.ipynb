# %%
import pandas as pd

# %%
df = pd.read_csv('../data/nasa_global_landslide_catalog_point.csv', index_col=0)

# %%
df.head(10).sort_values('event_date', ascending=False)
# Out:
#                                               Shape           source_name  \
# OBJECTID
# 10795830   (-117.26649999999995, 48.27970000000005)  The Spokesman-Review
# 10795829   (124.96680000000003, 10.700400000000059)  BusinessWorld Online
# 10795828   (123.89780000000007, 10.333600000000047)           The Freeman
# 10795827    (81.70800000000008, 28.837800000000072)               Reuters
# 10795825   (-122.66299999999995, 45.42000000000007)             Oregonian
# 10795833   (100.08450000000005, 23.890000000000043)                   UPI
# 10795824    (107.45000000000005, 32.56250000000006)                   AGU
# 10795832  (-114.41939999999994, 43.684600000000046)       MagicValley.com
# 10795831  (-107.62199999999996, 24.953100000000063)        Crónica Diaria
# 10795826   (-75.35869999999994, -11.12949999999995)              CBS News
#
#                                                 source_link  event_id  \
# OBJECTID
# ...
